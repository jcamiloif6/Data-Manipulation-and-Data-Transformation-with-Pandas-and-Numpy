# %%
import pandas as pd
# Out:
# /tmp/ipykernel_10353/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('estudiantes.csv')

# %%
df
# Out:
#     NOMBRE  EDAD GENERO       CARRERA SEMESTRE
# 0   Victor    28      M     Auditoria  Primero
# 1   Josefa    23      F   Informatica  Primero
# 2     Raul    26      M       Derecho   Quinto
# 3  Mariana    27      F   Informatica  Septimo
# 4  Rodrigo    22      M       Derecho  Tercero
# 5  Gustavo    25      M  Arquitectura  Septimo
# 6     Lucy    23      F   Informatica  Primero
# 7    Sofia    24      F      Economia   Noveno

# %%
df.iloc[1,3]
# Out:
# 'Informatica'

# %%
df.iloc[2,:3]
# Out:
# NOMBRE    Raul
# EDAD        26
# GENERO       M
# Name: 2, dtype: object

# %%
df.loc[1,'CARRERA']
# Out:
# 'Informatica'

# %%
df.loc[0:2,'NOMBRE']
# Out:
# 0    Victor
# 1    Josefa
# 2      Raul
# Name: NOMBRE, dtype: object

# %%
df.loc[2,'EDAD']
# Out:
# 26

# %%
df.loc[:3,('NOMBRE', 'CARRERA')]
# Out:
#     NOMBRE      CARRERA
# 0   Victor    Auditoria
# 1   Josefa  Informatica
# 2     Raul      Derecho
# 3  Mariana  Informatica

# %%
df.iloc[1,:3]
# Out:
# NOMBRE    Josefa
# EDAD          23
# GENERO         F
# Name: 1, dtype: object

# %%
df['TURNO'] = pd.Series(['Tarde', 'Noche', 'Noche', 'Noche', 'Tarde', 'Noche', 'Tarde'])

# %%
df
# Out:
#     NOMBRE  EDAD GENERO       CARRERA SEMESTRE  TURNO
# 0   Victor    28      M     Auditoria  Primero  Tarde
# 1   Josefa    23      F   Informatica  Primero  Noche
# 2     Raul    26      M       Derecho   Quinto  Noche
# 3  Mariana    27      F   Informatica  Septimo  Noche
# 4  Rodrigo    22      M       Derecho  Tercero  Tarde
# 5  Gustavo    25      M  Arquitectura  Septimo  Noche
# 6     Lucy    23      F   Informatica  Primero  Tarde
# 7    Sofia    24      F      Economia   Noveno    NaN

# %%
df.pop('SEMESTRE')
# Out:
# 0    Primero
# 1    Primero
# 2     Quinto
# 3    Septimo
# 4    Tercero
# 5    Septimo
# 6    Primero
# 7     Noveno
# Name: SEMESTRE, dtype: object

# %%
df
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO
# 0   Victor    28      M     Auditoria  Tarde
# 1   Josefa    23      F   Informatica  Noche
# 2     Raul    26      M       Derecho  Noche
# 3  Mariana    27      F   Informatica  Noche
# 4  Rodrigo    22      M       Derecho  Tarde
# 5  Gustavo    25      M  Arquitectura  Noche
# 6     Lucy    23      F   Informatica  Tarde
# 7    Sofia    24      F      Economia    NaN

# %%
df2 = pd.DataFrame({'NOMBRE': ['Alex'], 'EDAD': [23], 'GENERO':['M'], 'CARRERA':['Sociologia'], 'TURNO':['Tarde']})

# %%
df2
# Out:
#   NOMBRE  EDAD GENERO     CARRERA  TURNO
# 0   Alex    23      M  Sociologia  Tarde

# %%
df2 = pd.DataFrame(df2)

# %%
df2
# Out:
#   NOMBRE  EDAD GENERO     CARRERA  TURNO
# 0   Alex    23      M  Sociologia  Tarde

# %%
df = pd.concat([df, df2], ignore_index=True)

# %%
df.reset_index()
# Out:
#     index   NOMBRE  EDAD GENERO       CARRERA  TURNO           0
# 0       0   Victor  28.0      M     Auditoria  Tarde         NaN
# 1       1   Josefa  23.0      F   Informatica  Noche         NaN
# 2       2     Raul  26.0      M       Derecho  Noche         NaN
# 3       3  Mariana  27.0      F   Informatica  Noche         NaN
# 4       4  Rodrigo  22.0      M       Derecho  Tarde         NaN
# 5       5  Gustavo  25.0      M  Arquitectura  Noche         NaN
# 6       6     Lucy  23.0      F   Informatica  Tarde         NaN
# 7       7    Sofia  24.0      F      Economia    NaN         NaN
# 8       8      NaN   NaN    NaN           NaN    NaN      Carlos
# 9       9      NaN   NaN    NaN           NaN    NaN          27
# 10     10      NaN   NaN    NaN           NaN    NaN           M
# 11     11      NaN   NaN    NaN           NaN    NaN  Sociologia
# 12     12      NaN   NaN    NaN           NaN    NaN       Tarde

# %%
df
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO
# 0   Victor    28      M     Auditoria  Tarde
# 1   Josefa    23      F   Informatica  Noche
# 2     Raul    26      M       Derecho  Noche
# 3  Mariana    27      F   Informatica  Noche
# 4  Rodrigo    22      M       Derecho  Tarde
# 5  Gustavo    25      M  Arquitectura  Noche
# 6     Lucy    23      F   Informatica  Tarde
# 7    Sofia    24      F      Economia    NaN
# 8     Alex    23      M    Sociologia  Tarde

# %%
df.drop([1,2])
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO
# 0   Victor    28      M     Auditoria  Tarde
# 3  Mariana    27      F   Informatica  Noche
# 4  Rodrigo    22      M       Derecho  Tarde
# 5  Gustavo    25      M  Arquitectura  Noche
# 6     Lucy    23      F   Informatica  Tarde
# 7    Sofia    24      F      Economia    NaN
# 8     Alex    23      M    Sociologia  Tarde

# %%
df[(df['GENERO'] == 'F') & (df['EDAD'] >= 22)]
# Out:
#     NOMBRE  EDAD GENERO      CARRERA  TURNO
# 1   Josefa    23      F  Informatica  Noche
# 3  Mariana    27      F  Informatica  Noche
# 6     Lucy    23      F  Informatica  Tarde
# 7    Sofia    24      F     Economia    NaN

# %%
df
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO
# 0   Victor    28      M     Auditoria  Tarde
# 1   Josefa    23      F   Informatica  Noche
# 2     Raul    26      M       Derecho  Noche
# 3  Mariana    27      F   Informatica  Noche
# 4  Rodrigo    22      M       Derecho  Tarde
# 5  Gustavo    25      M  Arquitectura  Noche
# 6     Lucy    23      F   Informatica  Tarde
# 7    Sofia    24      F      Economia    NaN
# 8     Alex    23      M    Sociologia  Tarde

# %%
df.sort_values('CARRERA')
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO
# 5  Gustavo    25      M  Arquitectura  Noche
# 0   Victor    28      M     Auditoria  Tarde
# 2     Raul    26      M       Derecho  Noche
# 4  Rodrigo    22      M       Derecho  Tarde
# 7    Sofia    24      F      Economia    NaN
# 1   Josefa    23      F   Informatica  Noche
# 3  Mariana    27      F   Informatica  Noche
# 6     Lucy    23      F   Informatica  Tarde
# 8     Alex    23      M    Sociologia  Tarde

# %%
edad_atras = df.sort_values('EDAD')

# %%
edad_atras.tail()
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO
# 7    Sofia    24      F      Economia    NaN
# 5  Gustavo    25      M  Arquitectura  Noche
# 2     Raul    26      M       Derecho  Noche
# 3  Mariana    27      F   Informatica  Noche
# 0   Victor    28      M     Auditoria  Tarde

# %%
df.dropna()
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO
# 0   Victor    28      M     Auditoria  Tarde
# 1   Josefa    23      F   Informatica  Noche
# 2     Raul    26      M       Derecho  Noche
# 3  Mariana    27      F   Informatica  Noche
# 4  Rodrigo    22      M       Derecho  Tarde
# 5  Gustavo    25      M  Arquitectura  Noche
# 6     Lucy    23      F   Informatica  Tarde
# 8     Alex    23      M    Sociologia  Tarde

# %%
df.tail()
# Out:
#     NOMBRE  EDAD GENERO       CARRERA  TURNO
# 4  Rodrigo    22      M       Derecho  Tarde
# 5  Gustavo    25      M  Arquitectura  Noche
# 6     Lucy    23      F   Informatica  Tarde
# 7    Sofia    24      F      Economia    NaN
# 8     Alex    23      M    Sociologia  Tarde
